# %% [markdown]
# # TEST

# %%
# 參考資料
# https://github.com/SurpassHR/Youtube_SignatureCipher_Decryptor
# https://github.com/streamlink/streamlink/blob/master/src/streamlink/plugins/youtube.py
# https://github.com/ytdl-org/youtube-dl/blob/master/youtube_dl/extractor/youtube.py
# https://stackoverflow.com/questions/21510857/best-approach-to-decode-youtube-cipher-signature-using-php-or-js
# https://stackoverflow.com/a/68492807

# %%
#curl 'https://www.youtube.com/youtubei/v1/player?key=AIzaSyAO_FJ2SlqU8Q4STEHLGCilw_Y9_11qcW8' -H 'Content-Type: application/json' --data '{  "context": {    "client": {      "hl": "en",      "clientName": "WEB",      "clientVersion": "2.20210721.00.00",      "clientFormFactor": "UNKNOWN_FORM_FACTOR",   "clientScreen": "WATCH",      "mainAppWebInfo": {        "graftUrl": "/watch?v=UF8uR6Z6KLc",           }    },    "user": {      "lockedSafetyMode": false    },    "request": {      "useSsl": true,      "internalExperimentFlags": [],      "consistencyTokenJars": []    }  },  "videoId": "UF8uR6Z6KLc",  "playbackContext": {    "contentPlaybackContext": {        "vis": 0,      "splay": false,      "autoCaptionsDefaultOn": false,      "autonavState": "STATE_NONE",      "html5Preference": "HTML5_PREF_WANTS",      "lactMilliseconds": "-1"    }  },  "racyCheckOk": false,  "contentCheckOk": false}'

# %%
"""
Test URL

https://www.youtube.com/watch?v=UF8uR6Z6KLc
https://www.youtube.com/watch?v=piEyKyJ4pFg
"""
None

# %%
"""
The code found in https://www.youtube.com

"HL":"zh-TW",
"HTML_DIR":"ltr",
"HTML_LANG":"zh-Hant-TW",
"INNERTUBE_API_KEY":"AIzaSyAO_FJ2SlqU8Q4STEHLGCilw_Y9_11qcW8",
"INNERTUBE_API_VERSION":"v1",
"INNERTUBE_CLIENT_NAME":"WEB",
"INNERTUBE_CLIENT_VERSION":"2.20221024.10.00",
"INNERTUBE_CONTEXT":{"client":
  {"hl":"zh-TW",
   "gl":"TW",
   "remoteHost":"$YourIp",
   "deviceMake":"",
   "deviceModel":"",
   "visitorData":"$visitorData",
   "userAgent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.52,gzip(gfe)",
   "clientName":"WEB",
   "clientVersion":"2.20221024.10.00",
   "osName":"Windows",
   "osVersion":"10.0",
   "originalUrl":"https://www.youtube.com/",
   "platform":"DESKTOP",
   "clientFormFactor":"UNKNOWN_FORM_FACTOR",
   "configInfo":{
     "appInstallData":"$AppInstallData"
     },
     "timeZone":"Asia/Taipei",
     "browserName":"Edge Chromium",
     "browserVersion":"106.0.1370.52",
     "acceptHeader":"text/html,application/xhtml+xml,application/xml;q\u003d0.9,image/webp,image/apng,*/*;q\u003d0.8,application/signed-exchange;v\u003db3;q\u003d0.9",
     "deviceExperimentId":"$DeviceExperimentId"},
     "user":{
       "lockedSafetyMode":false
       },
       "request":{
         "useSsl":true
         },
       "clickTracking":{
         "clickTrackingParams":"IhMIkeSP34yA+wIVZ0gPAh20BQko"
         }
      },
"""
None

# %%
# https://github.com/wayne931121/Python_URL_Decode
def url_decoder(b):
# https://zh.wikipedia.org/zh-tw/%E7%99%BE%E5%88%86%E5%8F%B7%E7%BC%96%E7%A0%81
# %21 mean 21hex, => int("21",16) => 33 => chr(33) => "!", result: "!"
    if type(b)==bytes:
        b = b.decode(encoding="utf-8") #byte can't insert utf8 charater
    result = bytearray()
    enter_hex_unicode_mode = 0
    hex_tmp = ""
    now_index = 0
    for i in b:
        if i=='%': #like %51%52, have entered mode, continue appending bytearray
            enter_hex_unicode_mode = 1
            continue
        if enter_hex_unicode_mode:
            hex_tmp += i
            now_index += 1
            if now_index==2: #%51%5F len("51")=2 len("5F")=2
                result.append(int(hex_tmp, 16) )
                hex_tmp = ""
                now_index = 0
                enter_hex_unicode_mode = 0
            continue
        result.append(ord(i))
    result = result.decode(encoding="utf-8")
    return result

#保留字元的百分號編碼
URL_RFC_3986 = {
"!": "%21", "#": "%23", "$": "%24", "&": "%26", "'": "%27", "(": "%28", ")": "%29", "*": "%2A", "+": "%2B", 
",": "%2C", "/": "%2F", ":": "%3A", ";": "%3B", "=": "%3D", "?": "%3F", "@": "%40", "[": "%5B", "]": "%5D",
}

def url_encoder(b):
    # https://zh.wikipedia.org/wiki/%E7%99%BE%E5%88%86%E5%8F%B7%E7%BC%96%E7%A0%81
    if type(b)==bytes:
        b = b.decode(encoding="utf-8") #byte can't insert utf8 charater
    result = bytearray() #bytearray: rw, bytes: read-only
    for i in b:
        if i in URL_RFC_3986:
            for j in URL_RFC_3986[i]:
                result.append(ord(j))
            continue
        i = bytes(i, encoding="utf-8")
        if len(i)==1:
            result.append(ord(i))
        else:
            for c in i:
                c = hex(c)[2:].upper()
                result.append(ord("%"))
                result.append(ord(c[0:1]))
                result.append(ord(c[1:2]))
    result = result.decode(encoding="ascii")
    return result

encodeURIComponent = url_encoder
decodeURIComponent = url_decoder

# %%
# import re
# import ssl
# import json
# import socket

# # data = {
# #     "context": {
# #         "client": {      
# #             "hl": "zh-TW",      
# #             "clientName": "WEB",      
# #             "clientVersion": "2.20210721.00.00",      
# #             "clientFormFactor": "UNKNOWN_FORM_FACTOR",   
# #             "clientScreen": "WATCH",      
# #             "mainAppWebInfo": {        
# #                 "graftUrl": "/watch?v=piEyKyJ4pFg",           
# #             }    
# #         },    
# #         "user": {      
# #             "lockedSafetyMode": "false"    
# #         },    
# #         "request": {      
# #             "useSsl": "true",      
# #             "internalExperimentFlags": [],      
# #             "consistencyTokenJars": []    }  
# #     },  
# #     "videoId": "piEyKyJ4pFg",  
# #     "playbackContext": {    
# #         "contentPlaybackContext": {
# #             "vis": 0,      
# #             "splay": "false",      
# #             "autoCaptionsDefaultOn": "false",      
# #             "autonavState": "STATE_NONE",      
# #             "html5Preference": "HTML5_PREF_WANTS",      
# #             "lactMilliseconds": "-1"    
# #         }  
# #     },  "racyCheckOk": "false",  "contentCheckOk": "false"
# # }

# data = {
#     "videoId": "",
#     "contentCheckOk": False,
#     "racyCheckOk": False,
#     "context": {
#         "client": {
#             "clientName": "WEB",
#             "clientVersion": "2.20221014.01.00",
#             "userAgent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.52",
#             "platform": "DESKTOP",
#             "clientScreen": "EMBED",
#             "clientFormFactor": "UNKNOWN_FORM_FACTOR",
#             "browserName": "Chrome",
#         },
#         "user": {"lockedSafetyMode": "false"},
#         "request": {"useSsl": "true"},
#     }
# }

# def get_download_url():
#     print("TYPE A URL:")
#     url = "https://www.youtube.com/watch?v=piEyKyJ4pFg" #"https://www.youtube.com/watch?v=piEyKyJ4pFg" #input()
#     videoId = ""
#     if "youtu.be" in url:
#         videoId = url.split('/')[3] # "https://youtu.be/dQw4w9WgXcQ" >> "dQw4w9WgXcQ"
#     elif "watch?v=" in url:
#         videoId = url.split("watch?v=")[1].split('&')[0] # "https://www.youtube.com/watch?v=dQw4w9WgXcQ" >> "dQw4w9WgXcQ"
#     elif "/embed/" in url:
#         videoId = url.split("/embed/")[1] # "https://www.youtube.com/embed/dQw4w9WgXcQ" >> "dQw4w9WgXcQ"
#     # data["videoId"] = videoId
#     data_ = bytes(json.dumps(data), encoding="utf-8")
#     hostname = "www.youtube.com"
#     webpage = "https://www.youtube.com/youtubei/v1/player"
#     request = bytes("POST %s HTTP/1.1\r\nHost: %s:443\r\nContent-Type: application/json\r\nContent-Length: %d\r\nConnection: Close\r\n\r\n"%(webpage, hostname, len(data_)), encoding = "utf-8")
#     context = ssl._create_unverified_context() #ssl.create_default_context()
#     conn = context.wrap_socket(socket.socket(socket.AF_INET), server_hostname=hostname)
#     conn.connect((hostname, 443))
#     conn.send(request)
#     conn.send(data_)
#     recive = b""
#     print("Request:\n %s\n"%request)
#     while 1:
#         recive_tmp = conn.recv(1024)
#         if not recive_tmp: break #recive_tmp = b''
#         recive += recive_tmp
#     return recive
# content = get_download_url()
# # print(content.decode(encoding="utf-8"))

# content  # ($headers)\r\n\r\n(($content-length)\r\n($content)($content-length)\r\n($content)......)\r\n0\r\n\r\n, 0: $content-length=0, eof.
# content = content.split(b"0\r\n\r\n")[0] # ($headers)\r\n\r\n($content-length)\r\n($content)...($content-length)\r\n($contents)\r\n
# content = content.split(b"\r\n\r\n")[1]  # ($content-length)\r\n($contents)\r\n...($content-length)\r\n($contents)\r\n
# content = re.sub(b"[a-zA-z0-9]+\r\n", b"", content)
# content = content.decode(encoding="utf-8")
# content = json.loads(content)

# # for key in content: print(key)
# # for key in content['streamingData']: print(key)
# # for key in content['streamingData']["adaptiveFormats"]: print(key, end="\n\n")

# if content["streamingData"]["adaptiveFormats"]:
#     data = content["streamingData"]["adaptiveFormats"][-1]
# else:
#     data = content["streamingData"]["formats"][0]

# if "signatureCipher" in data:
#     a = [e.split("=") for e in data["signatureCipher"].split("&")]
#     url = a[2][1]
#     url = url_decoder(url)
#     sigcipher = a[0][1]
#     sigcipher = sigcipher.replace("%3D", "=")
#     print((url+"&alr=yes"+"&sig="+Rwa(sigcipher).replace("=","%3D")))
# else:
#     a = data["url"]
#     print(a)

# %%
import re
import json
import urllib.parse
import urllib.request

def request(url, headers={}):
    req = urllib.request.Request(url, headers = headers)
    response = urllib.request.urlopen(req)
    data = response.read()
    response.close()
    return data

def pretty_print(d):
    if "video" in d['mimeType']:
        i = [d['mimeType'], d['width'], d['height'], d['qualityLabel'].upper(), d['fps'], d['contentLength']]
        s = "Type: %s, W×H %d×%d %s, Fps %d, ContentLength %s. "%(*i, )
        print(s)
        return None
    if "audio" in d['mimeType']:
        i = [d['mimeType'], d['bitrate'], d['audioSampleRate'], d['audioChannels'], d['audioQuality'], d['contentLength']]
        s = "Type: %s, Bitrate %d, Rate %s, Channels %d, Quality %s, ContentLength %s. "%(*i, )
        print(s)
        return None

# %%
# The core function to decrypt
def Rwa(a):
    a=list(a);RB["ss"](a, 4);RB["jM"](a,6);RB["jM"](a,45);RB["e0"](a,3);return "".join(a)
def ss(a, *args):
    a.reverse()
def jM(a, b):
    c=a[0];a[0]=a[b%len(a)];a[b%len(a)]=c
def e0(a, b):
    for e in range(0,b)[::-1]: a.pop(e)

class Decrypt():
    def __init__(self):
        self.decrypt_function = [] # (self.elements, self.execute)
        self.signature_cipher = ""
        self.function_name = ""
        self.execute = [] # execute = [($function_name, $arg), ...]
        self.elements = {} # elements = {$function_name: $function, ...}
        return None
    def __call__(self, content):
        result = self.decrypt(content)
        return result
    def decrypt(self, content, prt=0):
        self.__init__()
        ######################################################################################################################
        """
        Regex:
        
        \w{2}=function\(a\){a=a\.split\(""\).+?return a\.join\(""\)};
        
        Example:
        
        EA=function(a){a=a.split("");DA.ss(a,4);DA.jM(a,6);DA.jM(a,45);DA.e0(a,3);return a.join("")};
        """
        decrypt = re.search('\\w{2}=function\\(a\\){a=a\\.split\\(""\\)(?P<elements>.+?)return a\\.join\\(""\\)};', content)
        if not decrypt: return -1
        if prt: print(decrypt[0])
        ######################################################################################################################
        """
        Regex:
        
        \w{2}.\w{2}\(a,\d+\)
        
        Example:
        
        DA.ss(a,4)
        DA.jM(a,6)
        DA.jM(a,45)
        DA.e0(a,3)
        """
        re.sub('(?P<function_name>\\w{2}).(?P<element_function_name>\\w{2})\\(a,(?P<arg>\\d+)\\)', self.process, decrypt[0])
        if not self.execute: return -2
        ######################################################################################################################
        """
        Regex:
        
        var %2s={(\w{2}:function\(a(,b)?\){.+?},?\n?)+};
        
        Example: 
        
        var DA={ss:function(a){a.reverse()},
        jM:function(a,b){var c=a[0];a[0]=a[b%a.length];a[b%a.length]=c},
        e0:function(a,b){a.splice(0,b)}};
        """
        core = re.search('var %s={(\\w{2}:function\\(a(,b)?\\){.+?},?\\n?)+};'%self.function_name, content)
        if not core: return -3
        core = core[0]
        if prt: print(core)
        ######################################################################################################################
        """
        Regex:
        
        \w{2}:function\(a\){a\.reverse\(\)}
        \w{2}:function\(a,b\){var c=a\[0\];a\[0\]=a\[b%a\.length\];a\[b%a\.length\]=c}
        \w{2}:function\(a,b\){a.splice\(0,b\)}
        
        Example:
        
        define elements                                                  => elements = {}
        ss:function(a){a.reverse()}                                      => elements["ss"]=ss
        jM:function(a,b){var c=a[0];a[0]=a[b%a.length];a[b%a.length]=c}  => elements["jM"]=jM
        e0:function(a,b){a.splice(0,b)}                                  => elements["e0"]=e0
        """
        # example elements = {"ss": ss, "jM": jM, "e0": e0}
        e = re.search('(?P<name>\\w{2}):function\\(a\\){a\\.reverse\\(\\)}', core)["name"]
        self.elements[e] = ss
        e = re.search('(?P<name>\\w{2}):function\\(a,b\\){var c=a\\[0\\];a\\[0\\]=a\\[b%a\\.length\\];a\\[b%a\\.length\\]=c}', core)["name"]
        self.elements[e] = jM
        e = re.search('(?P<name>\\w{2}):function\\(a,b\\){a.splice\\(0,b\\)}', core)["name"]
        self.elements[e] = e0
        ######################################################################################################################
        self.decrypt_function = (self.elements, self.execute)
        if prt:
            print(self.elements)
            print(self.execute)
        return self.decrypt_function
    def process(self, match):
        element_function_name = match["element_function_name"]
        arg = int(match["arg"])
        self.function_name = match["function_name"]
        self.execute.append((element_function_name, arg))
        return match[0]
    def Decrypt_Signature_Cipher(self, SignatureCipher):
        SignatureCipher = decodeURIComponent(SignatureCipher)
        SignatureCipher = list(SignatureCipher)
        for i in self.execute:
            function_name, arg = i
            function = self.elements[function_name]
            function(SignatureCipher, arg)
        SignatureCipher = encodeURIComponent(SignatureCipher)
        self.signature_cipher = SignatureCipher
        return SignatureCipher

# %%
content = request("https://www.youtube.com/s/player/19fc75cf/player_ias.vflset/zh_TW/base.js").decode(encoding="utf-8")
decrypt = Decrypt()
status = decrypt.decrypt(content, prt=1)
if type(status)==int and status<0: raise Exception("Error: code %d"%status)
decrypt.Decrypt_Signature_Cipher("==ab156cdefghijk")
# Out:
# wa=function(a){a=a.split("");RB.OP(a,55);RB.M3(a,52);RB.M3(a,34);return a.join("")};
# var RB={H4:function(a,b){a.splice(0,b)},
# OP:function(a){a.reverse()},
# M3:function(a,b){var c=a[0];a[0]=a[b%a.length];a[b%a.length]=c}};
# {'OP': <function ss at 0x0000020DB70D5DC0>, 'M3': <function jM at 0x0000020DB70D5F70>, 'H4': <function e0 at 0x0000020DB711B040>}
# [('OP', 55), ('M3', 52), ('M3', 34)]
# 'ijghkfedc651ba%3D%3D'

# %%
import re
import json
import urllib.parse
import urllib.request

prt = 0
print("Input a url")
url = input()
decrypt = Decrypt()
html = request(url)
yt = re.search(b"var ytInitialPlayerResponse = (?P<ytInitialPlayerResponse>{(?:[^;]+; codecs)*[^;]+);", html)
js = re.search(b'jsUrl":"(?P<url>.+?base.js)"', html) # Example:"jsUrl":"/s/player/19fc75cf/player_ias.vflset/zh_TW/base.js"

if not yt or not js:
    print("ERROR")
    print(content)
    raise Exception(-1)
yt = yt["ytInitialPlayerResponse"]
js = js["url"]
try:
    yt = json.loads(yt)
except Exception as e:
    print(e)
    print(yt)
    raise Exception(-2)

datas = yt["streamingData"]["adaptiveFormats"] if yt["streamingData"]["adaptiveFormats"] else yt["streamingData"]["formats"]
flag = "signatureCipher" in datas[0]
result = []
i = 0

if flag:
    js = 'https://www.youtube.com'+js.decode(encoding="utf-8")
    js = request(js).decode(encoding="utf-8")
    status = decrypt.decrypt(js, prt=prt)
    if (type(status)==int) and (status<0): raise Exception("Error: code %d"%status)

while i<len(datas):
    video_url = ""
    sigcipher = ""
    data = datas[i]
    if flag:
        a = [e.split("=") for e in data["signatureCipher"].split("&")]
        video_url = decodeURIComponent(a[2][1])
        sigcipher = a[0][1]
        if prt: print(sigcipher)
    else:
        video_url = data["url"]
    
    if sigcipher: 
        sigcipher = decrypt.Decrypt_Signature_Cipher(sigcipher)
        video_url = video_url+"&alr=yes&sig="+sigcipher
    i += 1
    print("\n")
    pretty_print(data)
    print(video_url)
    result.append(video_url)
print("complete")
# Out:
# Input a url
# https://www.youtube.com/watch?v=piEyKyJ4pFg
#
#
# Type: video/mp4; codecs="avc1.64002a", W×H 1920×1080 1080P60, Fps 60, ContentLength 11491441.
# ...

# %%
"""
{'itag': 299,
 'mimeType': 'video/mp4; codecs="avc1.64002a"',
 'bitrate': 546660,
 'width': 1920,
 'height': 1080,
 'initRange': {'start': '0', 'end': '741'},
 'indexRange': {'start': '742', 'end': '1289'},
 'lastModified': '1653309795831239',
 'contentLength': '11491441',
 'quality': 'hd1080',
 'fps': 60,
 'qualityLabel': '1080p60',
 'projectionType': 'RECTANGULAR',
 'averageBitrate': 395688,
 'approxDurationMs': '232333',
 'signatureCipher': 's=%3D%3DgBaICnTrEvCAN5N0IMYi3AHbTZro5r30D-zAIioKNzbDQIC0k5IxLGSOSQjFuOlTmXOAvOQUPetZAuA8kqCiF-U8qVgIQRw8JQ0qOY&sp=sig&url=https://rr5---sn-ipoxu-u2x6.googlevideo.com/videoplayback%3Fexpire%3D1666993313%26ei%3DQfhbY_y5Gczps8IPw_64oAM%26ip%3D2001%253Ab011%253A7006%253A3751%253Ae848%253A4c33%253Ad8f5%253Ae513%26id%3Do-AG146rgHBQr3s3YzcFkv9Xsnyj3v3vYoay8w7KU-2l-s%26itag%3D299%26aitags%3D133%252C134%252C135%252C136%252C160%252C242%252C243%252C244%252C247%252C278%252C298%252C299%252C302%252C303%252C394%252C395%252C396%252C397%252C398%252C399%26source%3Dyoutube%26requiressl%3Dyes%26mh%3Dg5%26mm%3D31%252C29%26mn%3Dsn-ipoxu-u2x6%252Csn-un57ene6%26ms%3Dau%252Crdu%26mv%3Dm%26mvi%3D5%26pl%3D53%26gcr%3Dtw%26vprv%3D1%26mime%3Dvideo%252Fmp4%26ns%3DFGauaFHcELbhjP7ZThNu5dMI%26gir%3Dyes%26clen%3D11491441%26dur%3D232.333%26lmt%3D1653309795831239%26mt%3D1666971441%26fvip%3D1%26keepalive%3Dyes%26fexp%3D24001373%252C24007246%26c%3DWEB%26txp%3D4535434%26n%3DzLH-5UL_KJJmpiLz%26sparams%3Dexpire%252Cei%252Cip%252Cid%252Caitags%252Csource%252Crequiressl%252Cgcr%252Cvprv%252Cmime%252Cns%252Cgir%252Cclen%252Cdur%252Clmt%26lsparams%3Dmh%252Cmm%252Cmn%252Cms%252Cmv%252Cmvi%252Cpl%26lsig%3DAG3C_xAwRAIgRP7MbwZLLIQ0frjkU3cBq8bp9VHjGUldTeeUaw6WGlQCIDTBL9qxfZEzmpClM7dY1se5HBLaQiTSMzSK3cnocEQA'}

{'itag': 251,
 'url': 'https://rr4---sn-ipoxu-u2x6.googlevideo.com/videoplayback?expire=1666991775&ei=P_JbY6OEBsOMvcAPoZmlOA&ip=2001%3Ab011%3A7006%3A3751%3Ae848%3A4c33%3Ad8f5%3Ae513&id=o-AIHR0i5m-J70QmwQ7xw8g0H7cA0mb9Od9fRM2SnmRzUp&itag=251&source=youtube&requiressl=yes&mh=-6&mm=31%2C29&mn=sn-ipoxu-u2x6%2Csn-un57ene6&ms=au%2Crdu&mv=m&mvi=4&pl=53&vprv=1&mime=audio%2Fwebm&ns=t9rn0vCl6DQy0fC5eb85fmUI&gir=yes&clen=11436230&dur=904.241&lmt=1651754218660056&mt=1666970004&fvip=5&keepalive=yes&fexp=24001373%2C24007246&c=WEB&txp=4532434&n=nIVxJUPF1B0hzwaz&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cvprv%2Cmime%2Cns%2Cgir%2Cclen%2Cdur%2Clmt&sig=AOq0QJ8wRQIhAJPCWsH0fOdNfoABn4Z9tcChsQ99dpOeCUCDdLi_HJo1AiA71xTwKdChARd8I4tkx5JuTNq0OzzriLXjeMy1-6x8DQ%3D%3D&lsparams=mh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpl&lsig=AG3C_xAwRAIgZidezBMa-wOKq2fb0eCTEU8CGzHGAoAQmwOiJU3TYv8CIDSeXGYctVBU148PKQQ7WvP1-Yazm2iGac4n9xM5nNPj',
 'mimeType': 'audio/webm; codecs="opus"',
 'bitrate': 120746,
 'initRange': {'start': '0', 'end': '265'},
 'indexRange': {'start': '266', 'end': '1809'},
 'lastModified': '1651754218660056',
 'contentLength': '11436230',
 'quality': 'tiny',
 'projectionType': 'RECTANGULAR',
 'averageBitrate': 101178,
 'audioQuality': 'AUDIO_QUALITY_MEDIUM',
 'approxDurationMs': '904241',
 'audioSampleRate': '48000',
 'audioChannels': 2,
 'loudnessDb': -9.3400002}
 """
None

# %%
"""
Test URL

https://www.youtube.com/watch?v=UF8uR6Z6KLc
https://www.youtube.com/watch?v=piEyKyJ4pFg
"""

# %%
url_encoder("我好棒==%%0.0:)")

# %% [markdown]
# # MAIN EXPLORE YOUTUBE DECRYPT SIGNATURE CIPHER FUNCTION

# %%
# sigcipher

# %%
# signatureCipher":"s=%3D%3Dw6yCKY2_WMkVykj1ueuu718vwGV72NNvtzCq_zR7ZLkBiAMkJV8LGnu14JkA2IfHvfEdxyB3mkVN8AoJ0hZA2cX7KAhIQRw8JQiqOAqO0\u0026sp=sig\u0026url=https://rr5---sn-ipoxu-u2x6.googlevideo.com/videoplayback%3Fexpire%3D1666824392%26ei%3DaGRZY7aWHd2S4QLk0oaYAg%26ip%3D1.171.31.91%26id%3Do-ALaRSVbBOVz-HmYwq5BH5TwXJLq9GZLlNyzrT0e5BRr6%26itag%3D299%26aitags%3D133%252C134%252C135%252C136%252C160%252C242%252C243%252C244%252C247%252C278%252C298%252C299%252C302%252C303%252C394%252C395%252C396%252C397%252C398%252C399%26source%3Dyoutube%26requiressl%3Dyes%26mh%3Dg5%26mm%3D31%252C29%26mn%3Dsn-ipoxu-u2x6%252Csn-un57ene6%26ms%3Dau%252Crdu%26mv%3Dm%26mvi%3D5%26pl%3D22%26gcr%3Dtw%26initcwndbps%3D821250%26vprv%3D1%26mime%3Dvideo%252Fmp4%26ns%3DxvfvP5FsfHehS92bIZ8fgekI%26gir%3Dyes%26clen%3D11491441%26dur%3D232.333%26lmt%3D1653309795831239%26mt%3D1666802473%26fvip%3D1%26keepalive%3Dyes%26fexp%3D24001373%252C24007246%26c%3DWEB%26txp%3D4535434%26n%3DaIDZOWRttzJfdrAh4L%26sparams%3Dexpire%252Cei%252Cip%252Cid%252Caitags%252Csource%252Crequiressl%252Cgcr%252Cvprv%252Cmime%252Cns%252Cgir%252Cclen%252Cdur%252Clmt%26lsparams%3Dmh%252Cmm%252Cmn%252Cms%252Cmv%252Cmvi%252Cpl%252Cinitcwndbps%26lsig%3DAG3C_xAwRAIgMFEk2Fg8tspVgkoDnL66i40OzkqQjkhx23QE8QvLJF4CIGtuK7u5_Lof8enr6QwN5Aw-ViQf6aCmGqkvDypila19"

# %%
# https://rr2---sn-ipoxu-u2xd.googlevideo.com/videoplayback?expire=1666810496&ei=IC5ZY86RD_u8vcAP0N2a-Ak&ip=2001%3Ab011%3A7006%3A32d0%3A45d0%3Aa813%3A3b1f%3A4ecb&id=o-AAhBrYBt0IymYU80frXYNChglHiigMjDVv8e8Mmj0qap&itag=251&source=youtube&requiressl=yes&mh=DE&mm=31%2C29&mn=sn-ipoxu-u2xd%2Csn-un57snee&ms=au%2Crdu&mv=m&mvi=2&pl=51&initcwndbps=927500&spc=yR2vpyZvujd_WxyIzLII9BYLasYAKhM&vprv=1&mime=audio%2Fwebm&ns=kCN-Lb-u8lCZS2rIdTL0E2cI&gir=yes&clen=1480776&dur=89.941&lmt=1649949745477723&mt=1666788552&fvip=1&keepalive=yes&fexp=24001373%2C24007246&c=WEB&txp=5532434&n=W-5y249v1vZM_g&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cspc%2Cvprv%2Cmime%2Cns%2Cgir%2Cclen%2Cdur%2Clmt&lsparams=mh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpl%2Cinitcwndbps&lsig=AG3C_xAwRgIhAJuVZZwj6UT6qhh2XzBYiumKjMSEd_q_NTgI-fPW9UVeAiEA6h68uf1IV7DIeuMCo5K5hNXrASTVz01YNkNk4w38MtY%3D&alr=yes&sig=AOq0QJ8wRQIhAKgbN8_J1pDuaBqsKNW7mELYMI0oAzEbtNdMemNd4TyJAiASKvpWTksAHwcJy0pxuiiMtK2pV_ICYMIElhLt2jPB5Q%3D%3D&cpn=ymYM7ytIxuu8OBqm&cver=2.20221024.10.00&range=502082-841056&rn=53&rbuf=22569&pot=DwSFvhVL8OSmBL18uDSXJvxOIph-XZfCA6SyN

# %%
import re
import urllib.parse
import urllib.request

def request(url):
    req = urllib.request.Request(url)
    response = urllib.request.urlopen(req)
    data = response.read()
    response.close()
    return data
url = 'https://www.youtube.com/'
data = request(url)
js = re.search(b'"jsUrl":"(?P<basejs>.+?base.js)"', data)["basejs"].decode(encoding="utf-8")
js = url[:-1]+js
print(js)
js = request(js)

# %%
# f = open("base.js", "rb")
# js = f.read().decode(encoding="utf-8")
# f.close()
js = js.decode(encoding="utf-8")
######## from https://github.com/ytdl-org/youtube-dl/blob/master/youtube_dl/extractor/youtube.py ############
regex = (r'\b[cs]\s*&&\s*[adf]\.set\([^,]+\s*,\s*encodeURIComponent\s*\(\s*(?P<sig>[a-zA-Z0-9$]+)\(',
         r'\b[a-zA-Z0-9]+\s*&&\s*[a-zA-Z0-9]+\.set\([^,]+\s*,\s*encodeURIComponent\s*\(\s*(?P<sig>[a-zA-Z0-9$]+)\(',
         r'\bm=(?P<sig>[a-zA-Z0-9$]{2,})\(decodeURIComponent\(h\.s\)\)',
         r'\bc&&\(c=(?P<sig>[a-zA-Z0-9$]{2,})\(decodeURIComponent\(c\)\)',
         r'(?:\b|[^a-zA-Z0-9$])(?P<sig>[a-zA-Z0-9$]{2,})\s*=\s*function\(\s*a\s*\)\s*{\s*a\s*=\s*a\.split\(\s*""\s*\);[a-zA-Z0-9$]{2}\.[a-zA-Z0-9$]{2}\(a,\d+\)',
         r'(?:\b|[^a-zA-Z0-9$])(?P<sig>[a-zA-Z0-9$]{2,})\s*=\s*function\(\s*a\s*\)\s*{\s*a\s*=\s*a\.split\(\s*""\s*\)',
         r'(?P<sig>[a-zA-Z0-9$]+)\s*=\s*function\(\s*a\s*\)\s*{\s*a\s*=\s*a\.split\(\s*""\s*\)',
         # Obsolete patterns
         r'(["\'])signature\1\s*,\s*(?P<sig>[a-zA-Z0-9$]+)\(',
         r'\.sig\|\|(?P<sig>[a-zA-Z0-9$]+)\(',
         r'yt\.akamaized\.net/\)\s*\|\|\s*.*?\s*[cs]\s*&&\s*[adf]\.set\([^,]+\s*,\s*(?:encodeURIComponent\s*\()?\s*(?P<sig>[a-zA-Z0-9$]+)\(',
         r'\b[cs]\s*&&\s*[adf]\.set\([^,]+\s*,\s*(?P<sig>[a-zA-Z0-9$]+)\(',
         r'\b[a-zA-Z0-9]+\s*&&\s*[a-zA-Z0-9]+\.set\([^,]+\s*,\s*(?P<sig>[a-zA-Z0-9$]+)\(',
         r'\bc\s*&&\s*a\.set\([^,]+\s*,\s*\([^)]*\)\s*\(\s*(?P<sig>[a-zA-Z0-9$]+)\(',
         r'\bc\s*&&\s*[a-zA-Z0-9]+\.set\([^,]+\s*,\s*\([^)]*\)\s*\(\s*(?P<sig>[a-zA-Z0-9$]+)\(',
         r'\bc\s*&&\s*[a-zA-Z0-9]+\.set\([^,]+\s*,\s*\([^)]*\)\s*\(\s*(?P<sig>[a-zA-Z0-9$]+)\(')
#############################################################################################################

# %%
data = []
for i in regex:
    match = re.search(i, js)
    if match:
        data.append((i, js))
        print(i)
        print(match[0], end="\n\n")

# %%
# https://rr5---sn-ipoxu-u2x6.googlevideo.com/videoplayback?expire=1666815829&ei=9UJZY8asK9bugQPjraOYDQ&ip=2001%3Ab011%3A7006%3A32d0%3A45d0%3Aa813%3A3b1f%3A4ecb&id=o-ANXhZeKmPLbhP_hnATcbPo8G7ub3rJK_dW7IGPo_JlB6&itag=299&aitags=133%2C134%2C135%2C136%2C160%2C242%2C243%2C244%2C247%2C278%2C298%2C299%2C302%2C303%2C394%2C395%2C396%2C397%2C398%2C399&source=youtube&requiressl=yes&mh=g5&mm=31%2C29&mn=sn-ipoxu-u2x6%2Csn-un57ene6&ms=au%2Crdu&mv=m&mvi=5&pl=51&gcr=tw&initcwndbps=867500&vprv=1&mime=video%2Fmp4&ns=S2VxeDvy17n7RNMFa0g7KVMI&gir=yes&clen=11491441&dur=232.333&lmt=1653309795831239&mt=1666793827&fvip=1&keepalive=yes&fexp=24001373%2C24007246&c=WEB&txp=4535434&n=6YuOFDqP67UlzPb8gi&sparams=expire%2Cei%2Cip%2Cid%2Caitags%2Csource%2Crequiressl%2Cgcr%2Cvprv%2Cmime%2Cns%2Cgir%2Cclen%2Cdur%2Clmt&lsparams=mh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpl%2Cinitcwndbps&lsig=AG3C_xAwRgIhAOyOpLyqx9hFENHXOVWmOJao7w-EWzop6YpIKFaZ8XATAiEA7rd3PRT5FJdTfDuLxsVHksHZiiIMe2-wWIpC8Ar8EQo%3D&alr=yes&sig=AOq0QJ8wRgIhAIeTpAgNMXa6Fc41C2OE2zUamHHZWmO2C_wHCKvYpPwKAiEA-hSNl2vYNoGR0GccGbKNSFqFJesj2jPf16LU4THs9IM%3D

# %%
"""
From base.js 2022.10.26

### This Rwa Function will decrypt signatureChiper ###
Rwa=function(a){a=a.split("");RB.ss(a,4);RB.jM(a,6);RB.jM(a,45);RB.e0(a,3);return a.join("")};
var RB={ss:function(a){a.reverse()},
jM:function(a,b){var c=a[0];a[0]=a[b%a.length];a[b%a.length]=c},
e0:function(a,b){a.splice(0,b)}};

QE = function(a, b, c) {  ### This Function will decrypt signatureChiper ###
    b = void 0 === b ? "" : b;
    c = void 0 === c ? "" : c;
    a = new g.SB(a,!0);
    a.set("alr", "yes");
    c && (c = Rwa(decodeURIComponent(c)), ### This Line will decrypt signatureChiper ###
    a.set(b, encodeURIComponent(c)));
    return a
}

UBa = function(a, b) { ### This Function will decrypt signatureChiper ###
        if (!b || !oCa(a))
            return null;
        rI(a, "html5_enable_cobalt_experimental_vp9_decoder") && (ZE = !0);
        b = tI(b);
        var c = a.od;
        var d = a.lengthSeconds
          , e = a.isLivePlayback
          , f = a.Ce
          , h = a.B
          , l = a.videoId
          , m = Nya(b);
        if (e || f) {
            something not important...
            
        } else if ("FORMAT_STREAM_TYPE_OTF" === m) {
            something not important...
            
        } else {
            d = void 0 === d ? 0 : d;
            f = new KE("",null == h ? void 0 : h.experiments,!1,l);
            f.duration = d || 0;
            h = g.t(b);
            for (l = h.next(); !l.done; l = h.next())
                m = l.value,
                l = PE(m, c, f.duration),
                d = jD(m.init),
                e = jD(m.index),
                (m = QE(m.url, m.sp, m.s)) && LE(f, new OD(m,l,d,e)); ### This Line will decrypt signatureChiper ###
            c = f
        }
        something not important...
        return c
    }
    ;
"""
0

"""
# https://www.youtube.com/s/player/64588dad/player_ias.vflset/zh_TW/base.js

Qwa=function(a){a=a.split("");PB.Co(a,14);PB.Co(a,14);PB.Zo(a,56);PB.GZ(a,2);return a.join("")};
var PB={Co:function(a,b){var c=a[0];a[0]=a[b%a.length];a[b%a.length]=c},
Zo:function(a){a.reverse()},
GZ:function(a,b){a.splice(0,b)}};

Rwa=function(a){a=a.split("");RB.ss(a,4);RB.jM(a,6);RB.jM(a,45);RB.e0(a,3);return a.join("")};
var RB={ss:function(a){a.reverse()},
jM:function(a,b){var c=a[0];a[0]=a[b%a.length];a[b%a.length]=c},
e0:function(a,b){a.splice(0,b)}};

# %%
def Rwa(a):
    a=list(a);RB["ss"](a, 4);RB["jM"](a,6);RB["jM"](a,45);RB["e0"](a,3);return "".join(a)
def ss(a, *args):
    a.reverse()
    #print(a)
def jM(a, b):
    c=a[0];a[0]=a[b%len(a)];a[b%len(a)]=c
    #print(a)
def e0(a, b):
    for e in range(0,b)[::-1]: a.pop(e)

RB = {"ss": ss, "jM": jM, "e0": e0}

def Qwa(a):
    a=list(a)
    jM(a, 14)
    jM(a, 14)
    ss(a, 56)
    e0(a, 2)
    return "".join(a)

# %%
Rwa("abcdefghijk")

# %%
"""
The URL found in browser devoloper tools network.

https://rr2---sn-ipoxu-u2xd.googlevideo.com/videoplayback
# ?expire=1666030612
&ei=s0dNY4D8N4_L4gKj_6W4DA
&ip=2001%3Ab011%3A7006%3A109f%3A2902%3Acd20%3Ac4b7%3A2d0b
&id=o-ADSt-Dc1H7Q5Fh0u9DYYJ4KrfvkY4xYApdugn_TWH-Mx
&itag=397
&aitags=133%2C134%2C135%2C136%2C137%2C160%2C242%2C243%2C244%2C247%2C248%2C278%2C394%2C395%2C396%2C397%2C398%2C399
&source=youtube
&requiressl=yes
&mh=DE
&mm=31%2C29
&mn=sn-ipoxu-u2xd%2Csn-un57enez
&ms=au%2Crdu
&mv=m
&mvi=2
&pl=55
&initcwndbps=618750
&vprv=1
&mime=video%2Fmp4
&ns=NYGUqkcK04P8dcrKvPAAXMYI
&gir=yes
&clen=6359636
&dur=89.923
&lmt=1649950455832741
&mt=1666008570
&fvip=2
&keepalive=yes
&fexp=24001373%2C24007246
&c=WEB
&txp=5532434
&n=joS1eFfh9qck0w
&sparams=expire%2Cei%2Cip%2Cid%2Caitags%2Csource%2Crequiressl%2Cvprv%2Cmime%2Cns%2Cgir%2Cclen%2Cdur%2Clmt
&lsparams=mh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpl%2Cinitcwndbps
&lsig=AG3C_xAwRAIgEGPSDPsvGth9z2g1rEvuKP1eUuGxGq5jNIrkssIxikwCIBaNbIZsrRR14YUUqWbuyQ1m4nzNAYxqWkkHbi0IK28m
&alr=yes
&sig=AOq0QJ8wRQIhAPj1Q8qZRwKfNmBC9IpAI8Qab4qTJsChN5jr-FFk9FMEAiBuolU5K1jlOKOrAPVwCv7RkjhB_hJx_u_IPvalzHFf3w%3D%3D
&cpn=fTZoAZg6zQD6Bi6f
&cver=2.20221014.01.00
&range=0-184232
&rn=1
&rbuf=0
&altitags=396%2C395
"""

# %%
s = "s=%3D%3Dw6yCKY2_WMkVykj1ueuu718vwGV72NNvtzCq_zR7ZLkBiAMkJV8LGnu14JkA2IfHvfEdxyB3mkVN8AoJ0hZA2cX7KAhIQRw8JQiqOAqO0\u0026sp=sig\u0026url=https://rr5---sn-ipoxu-u2x6.googlevideo.com/videoplayback%3Fexpire%3D1666824392%26ei%3DaGRZY7aWHd2S4QLk0oaYAg%26ip%3D1.171.31.91%26id%3Do-ALaRSVbBOVz-HmYwq5BH5TwXJLq9GZLlNyzrT0e5BRr6%26itag%3D299%26aitags%3D133%252C134%252C135%252C136%252C160%252C242%252C243%252C244%252C247%252C278%252C298%252C299%252C302%252C303%252C394%252C395%252C396%252C397%252C398%252C399%26source%3Dyoutube%26requiressl%3Dyes%26mh%3Dg5%26mm%3D31%252C29%26mn%3Dsn-ipoxu-u2x6%252Csn-un57ene6%26ms%3Dau%252Crdu%26mv%3Dm%26mvi%3D5%26pl%3D22%26gcr%3Dtw%26initcwndbps%3D821250%26vprv%3D1%26mime%3Dvideo%252Fmp4%26ns%3DxvfvP5FsfHehS92bIZ8fgekI%26gir%3Dyes%26clen%3D11491441%26dur%3D232.333%26lmt%3D1653309795831239%26mt%3D1666802473%26fvip%3D1%26keepalive%3Dyes%26fexp%3D24001373%252C24007246%26c%3DWEB%26txp%3D4535434%26n%3DaIDZOWRttzJfdrAh4L%26sparams%3Dexpire%252Cei%252Cip%252Cid%252Caitags%252Csource%252Crequiressl%252Cgcr%252Cvprv%252Cmime%252Cns%252Cgir%252Cclen%252Cdur%252Clmt%26lsparams%3Dmh%252Cmm%252Cmn%252Cms%252Cmv%252Cmvi%252Cpl%252Cinitcwndbps%26lsig%3DAG3C_xAwRAIgMFEk2Fg8tspVgkoDnL66i40OzkqQjkhx23QE8QvLJF4CIGtuK7u5_Lof8enr6QwN5Aw-ViQf6aCmGqkvDypila19"
a = [e.split("=") for e in s.split("&")]
url = a[2][1]
url = url_decoder(url)
sigcipher = a[0][1]
sigcipher = url_decoder(sigcipher)
sigcipher = Rwa(sigcipher)
sigcipher = url_encoder(sigcipher)
print((url+"&alr=yes"+"&sig="+sigcipher))
